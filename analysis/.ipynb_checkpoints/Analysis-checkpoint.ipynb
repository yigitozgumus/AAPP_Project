# %% [markdown]
# # Strongly Connected Components Space Complexity Analysis

# %% [markdown]
# ### Import Required Libraries

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import scipy as sp
import bokeh as bkh
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join

# All outputs are visible
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
#Retina resolution for the plots
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
# All plots contained in the notebook
# %matplotlib inline

# visualization library
import seaborn as sns
sns.set( color_codes=True)
sns.set_context(rc={"font.family":'sans',"font.size":24,"axes.titlesize":20,"axes.labelsize":16}) 
sns.set_palette("husl")

# %% [markdown]
# ## Implementation of code to select the experiment file and visualization of graphs

# %%
def print_available_cvs():
    data = "../data"
    experiment_csvs = [("data/" + f) for f in listdir(data) if (isfile(join(data, f)) and f[-3:] == 'csv')]
    print("The current experiment list is:")
    for f in range(len(experiment_csvs)):
        print(str(f) + "-) " + experiment_csvs[f] )
        
def get_data(index):
    data = "../data"
    experiment_csvs = [("data/" + f) for f in listdir(data) if (isfile(join(data, f)) and f[-3:] == 'csv')]
    names = ["id","Vertex","Edge",
         'T-Tarjan','S-Tarjan',
         'T-Nuutila Original','S-Nuutila Original', 
         'T-Nuutila Version1','S-Nuutila Version1',
         'T-Nuutila Version2','S-Nuutila Version2', 
         'T-Pearson Version1','S-Pearson Version1',
         'T-Pearson Version2','S-Pearson Version2',
         'T-Pearson Version3','S-Pearson Version3']
    file = "../"+ experiment_csvs[index]
    print("\n The file that is used to create the dataframe is : " + file)
    df = pd.read_csv(file,sep=',',names=names)
    return df

def seperate_dataframes(df,maxIndex):
    df_storage_all = df[['Vertex','S-Tarjan',
                 'S-Nuutila Original', 
                 'S-Nuutila Version1',
                 'S-Nuutila Version2', 
                 'S-Pearson Version1',
                 'S-Pearson Version2',
                'S-Pearson Version3']]
    df_storage_all = df_storage_all.sort_values(by=['Vertex']);
    
    df_edges = df[['Vertex','Edge']].sort_values(by=['Vertex'])
    
    df_s_t = df_storage_all[['Vertex','S-Tarjan']]
    df_s_n = df_storage_all[['Vertex',
                                     'S-Nuutila Original', 
                                     'S-Nuutila Version1',
                                     'S-Nuutila Version2', ]]
    df_s_p = df_storage_all[['Vertex',
                                   'S-Pearson Version1',
                                    'S-Pearson Version2',
                                    'S-Pearson Version3']]
    bundle = [df_edges[:maxIndex],df_s_n[:maxIndex],df_s_p[:maxIndex],df_storage_all[:maxIndex]]
    return bundle

def seperate_dataframes_t(df,maxIndex):
    df_storage_all = df[['Vertex','T-Tarjan',
                 'T-Nuutila Original', 
                 'T-Nuutila Version1',
                 'T-Nuutila Version2', 
                 'T-Pearson Version1',
                 'T-Pearson Version2',
                'T-Pearson Version3']]
    df_storage_all = df_storage_all.sort_values(by=['Vertex']);
    
    df_edges = df[['Vertex','Edge']].sort_values(by=['Vertex'])
    
    df_s_t = df_storage_all[['Vertex','T-Tarjan']]
    df_s_n = df_storage_all[['Vertex',
                                     'T-Nuutila Original', 
                                     'T-Nuutila Version1',
                                     'T-Nuutila Version2', ]]
    df_s_p = df_storage_all[['Vertex',
                                   'T-Pearson Version1',
                                    'T-Pearson Version2',
                                    'T-Pearson Version3']]
    bundle = [df_edges[:maxIndex],df_s_n[:maxIndex],df_s_p[:maxIndex],df_storage_all[:maxIndex]]
    return bundle

def plot_storage(df,title,axe=None):
    
    if (axe != None):
        for i in range(1,len(df.columns)):
            axe.plot(df['Vertex'],df[df.columns[i]])
        if("Edge" in df.columns):
            axe.set_ylabel('Edge Count')
        else:
            axe.set_ylabel('Kilobytes')
        axe.legend(loc='best')  
        axe.set_xlabel('Vertex Count')
        axe.set_title(title)
    else:
        plt.figure(figsize = (12,12))
        for i in range(1,len(df.columns)):
            plt.plot(df['Vertex'],df[df.columns[i]])
        if("Edge" in df.columns):
            plt.set_ylabel('Edge Count')
        else:
            plt.ylabel('Kilobytes')
        plt.legend(loc='best')  
        plt.xlabel('Vertex Count')
        plt.title(title)
    
def plot_comparisons(bundle):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2,figsize=(14,14))
    titles = ["Edge Count With Respect to Vertices",
             "Storage Performance of Nuutila Implementations",
             "Storage Performance of Pearce Implementations",
             "Storage Performance of All Algorithms"]
    axs = [ax1,ax2,ax3, ax4]
    for i in range(len(bundle)):
        plot_storage(bundle[i],titles[i],axs[i])

# %% [markdown]
# ## Print the current experiments

# %%
print_available_cvs()
# Out:
# The current experiment list is:
# 0-) data/experiment_2018-07-13.00:45:04.csv
# 1-) data/experiment_2018-07-12.19:35:55.csv
# 2-) data/experiment_2018-07-12.14:34:02.csv
# 3-) data/experiment_2018-07-10.22:19:31.csv
# 4-) data/experiment_2018-07-13.00:56:40.csv
# 5-) data/experiment_2018-07-12.17:52:58.csv
# 6-) data/experiment_2018-07-11.21:06:31.csv
# 7-) data/experiment_2018-07-17.20:00:36.csv
# 8-) data/experiment_2018-07-14.11:02:43.csv
# 9-) data/experiment_2018-07-12.19:27:31.csv
# 10-) data/experiment_2018-07-12.19:09:53.csv
# 11-) data/experiment_2018-06-28.11:09:41.csv
# 12-) data/experiment_2018-06-28.21:30:23.csv
# 13-) data/experiment_2018-07-14.11:04:14.csv
# 14-) data/experiment_2018-06-29.09:26:39.csv
# 15-) data/experiment_2018-07-12.14:28:42.csv
# 16-) data/experiment_2018-07-03.08:34:40.csv
# 17-) data/experiment_2018-07-13.00:38:25.csv
# 18-) data/experiment_2018-07-01.12:42:11.csv

# %% [markdown]
# ## Select the latest one

# %%
df = get_data(13)
df.shape
# Out:
#  The file that is used to create the dataframe is : ../data/experiment_2018-07-14.11:04:14.csv
# (88448, 17)

# %% [markdown]
# ## Let's See the general statistics about the experiment

# %%
df.shape
df.describe()
# Out:
# (88448, 17)
#                  id        Vertex           Edge       T-Tarjan      S-Tarjan  \
# count  88448.000000  88448.000000   88448.000000   88448.000000  88448.000000
# mean   44223.500000    227.618646   40224.279384    3065.884538      4.446468
# std    25532.882642    260.968284   89946.817538    8493.345781      5.098874
# min        0.000000      5.000000       0.000000       0.007571      0.097656
# 25%    22111.750000     44.000000     419.000000       3.085650      0.859375
# 50%    44223.500000     88.000000    2768.000000      30.727350      1.718750
# 75%    66335.250000    363.000000   31430.750000    1395.672500      7.089840
# max    88447.000000    999.000000  731129.000000  179267.000000     19.519500
#
#        T-Nuutila Original  S-Nuutila Original  T-Nuutila Version1  \
# count        88448.000000        88448.000000        88448.000000
# mean             4.559573            7.113083            5.151199
# std             10.060149            8.155259           11.446442
# min              0.002458            0.156250            0.001851
# 25%              0.083037            1.375000            0.087069
# 50%              0.383471            2.750000            0.418494
# 75%              3.704825           11.343800            4.121630
# max            183.533000           31.218800          308.674000
#
#        S-Nuutila Version1  T-Nuutila Version2  S-Nuutila Version2  \
# count        88448.000000        88448.000000        88448.000000
# mean             7.074662            4.667395            5.357315
# std              8.155682           10.302503            6.117035
# min              0.117188            0.001818            0.136719
# 25%              1.335940            0.077733            1.050780
# 50%              2.710940            0.378385            2.082030
# 75%             11.304700            3.750113            8.527340
# max             31.210900          161.439000           23.714800
#
#        T-Pearson Version1  S-Pearson Version1  T-Pearson Version2  \
# count        88448.000000        88448.000000        88448.000000
# mean             4.876961            7.074662            3.505042
# std             10.773314            8.155682            7.799803
# min              0.001999            0.117188            0.001380
# 25%              0.088089            1.335940            0.063548
# 50%              0.410308            2.710940            0.289910
# 75%              3.991325           11.304700            2.821907
# max            381.703000           31.210900          267.103000
#
#        S-Pearson Version2  T-Pearson Version3  S-Pearson Version3
# count        88448.000000        88448.000000        88448.000000
# mean             2.632894           16.371880            8.852935
# std              3.063243           36.422651           10.193951
# min              0.023438            0.003013            0.156250
# 25%              0.476562            0.248736            1.685547
# 50%              1.007810            1.284470            3.390620
# 75%              4.219727           13.028550           14.132800
# max             11.703100          627.877000           39.015600

# %% [markdown]
# ## Plot the Storage Trends with respect to the each implemented algorithm, with the number of edges to explain the shape of the graph

# %% [markdown]
# ### First 5000 Graphs

# %%
new_df_5000 = seperate_dataframes(df,5000)
plot_comparisons(new_df_5000)

# %% [markdown]
# ### First 10000 Graphs

# %%
new_df_10000 = seperate_dataframes(df,10000)
plot_comparisons(new_df_10000)

# %% [markdown]
# ### First 15000 Graphs

# %%
new_df_15000 = seperate_dataframes(df,15000)
plot_comparisons(new_df_15000)

# %% [markdown]
# ### First 25000 Graphs

# %%
new_df_25000 = seperate_dataframes(df,25000)
plot_comparisons(new_df_25000)

# %% [markdown]
# ### First 50000 Graphs

# %%
new_df_50000 = seperate_dataframes(df,50000)
plot_comparisons(new_df_50000)

# %% [markdown]
# ### First 75000 Experiments

# %%
new_df_75000 = seperate_dataframes(df,75000)
plot_comparisons(new_df_75000)

# %% [markdown]
# ### All Experiments

# %%
new_dfs = seperate_dataframes(df,df.shape[0])
plot_comparisons(new_dfs)

# %% [markdown]
# ## Plot the Storage Trends with respect to the each implemented algorithm, with the number of edges to explain the shape of the graph

# %%
new_dfs = seperate_dataframes_t(df,df.shape[0])

# %%
new_dfs[0].head()
new_dfs[1].head()
new_dfs[2].head()
new_dfs[3].head()
new_dfs[4].head()
# Out:
#        Vertex  Edge
# 5243        5    12
# 17296       5     7
# 7576        5     4
# 7581        5     3
# 16135       5     5
#        Vertex  T-Nuutila Original  T-Nuutila Version1  T-Nuutila Version2
# 5243        5            0.006103            0.005472            0.004113
# 17296       5            0.007382            0.005946            0.006607
# 7576        5            0.006894            0.005501            0.006042
# 7581        5            0.007439            0.004740            0.004691
# 16135       5            0.004098            0.003519            0.003565
#        Vertex  T-Pearson Version1  T-Pearson Version2  T-Pearson Version3
# 5243        5            0.005737            0.004240            0.013535
# 17296       5            0.006129            0.004285            0.015330
# 7576        5            0.005990            0.004047            0.011684
# 7581        5            0.005697            0.003529            0.013983
# 16135       5            0.003816            0.002650            0.008425
#        Vertex  T-Tarjan  T-Nuutila Original  T-Nuutila Version1  \
# 5243        5  0.027419            0.006103            0.005472
# 17296       5  0.033320            0.007382            0.005946
# 7576        5  0.032143            0.006894            0.005501
# 7581        5  0.029629            0.007439            0.004740
# 16135       5  0.021711            0.004098            0.003519
#
#        T-Nuutila Version2  T-Pearson Version1  T-Pearson Version2  \
# 5243             0.004113            0.005737            0.004240
# 17296            0.006607            0.006129            0.004285
# 7576             0.006042            0.005990            0.004047
# 7581             0.004691            0.005697            0.003529
# 16135            0.003565            0.003816            0.002650
#
#        T-Pearson Version3
# 5243             0.013535
# 17296            0.015330
# 7576             0.011684
# 7581             0.013983
# 16135            0.008425
#        Vertex  T-Tarjan
# 5243        5  0.027419
# 17296       5  0.033320
# 7576        5  0.032143
# 7581        5  0.029629
# 16135       5  0.021711

# %%
plt.figure(figsize = (12,12))
#plt.plot(new_dfs[0]['Vertex'],new_dfs[0]['Edge'])
plt.plot(new_dfs[1]['Vertex'],new_dfs[1]['T-Nuutila Version2'])
